# %%
from torch.utils.data import Dataset, DataLoader
import torch
import random
import albumentations as A
from albumentations.pytorch import ToTensorV2
import torch.nn as nn
import torch.optim as optim
from torchvision import models
from torchvision.transforms import RandomErasing
from sklearn.metrics import roc_auc_score, f1_score, confusion_matrix

from collections import Counter
import numpy as np
import cv2
import os
import pandas as pd
from torch.cuda.amp import autocast, GradScaler


####### model paramters 

task_name='FGS_ensemble'


train_dir = 'TRAIN'
test_pre = 'TEST' 

root_folder='RESULTS' 



save_folder = os.path.join(root_folder,task_name)

os.makedirs(save_folder, exist_ok=True)
txt_fname=os.path.join(save_folder,task_name+'.txt')
save_model_path=os.path.join(save_folder,task_name+'best_model.pth')
# Out:
# /home/tanmoy/anaconda3/lib/python3.11/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 2.0.0 (you have 1.4.14). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
def set_seed(no):
    torch.manual_seed(no)
    random.seed(no)
    np.random.seed(no)
    os.environ['PYTHONHASHSEED'] = str()
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

set_seed(100)

# %%
##### custom data set 

class CustomDataset(Dataset):
    def __init__(self, root_dir, csv_path, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.image_paths = []
        self.class_labels = []
        self.severity_scores = {}
        self._load_severity_scores(csv_path)
        self._load_dataset()

    def _load_severity_scores(self, csv_path):
        # Read the CSV file
        df = pd.read_csv(csv_path)
        # Assuming the CSV has columns 'filename' and 'severity_score'
        for _, row in df.iterrows():
            self.severity_scores[row['filename']] = row['severity_category']

    def _load_dataset(self):
        for class_label, class_dir in enumerate(['HEALTHY', 'ABNORMAL']):  # 0: HEALTHY, 1: ABNORMAL
            class_dir_path = os.path.join(self.root_dir, class_dir)
            if not os.path.exists(class_dir_path):
                print(f"Directory not found: {class_dir_path}")
                continue
            for filename in os.listdir(class_dir_path):
                if filename.endswith(('.jpg', '.jpeg', '.png')):
                    self.image_paths.append(os.path.join(class_dir_path, filename))
                    self.class_labels.append(class_label)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        class_label = self.class_labels[idx]
        image_path = self.image_paths[idx]
        filename = os.path.basename(image_path)
        severity_score = self.severity_scores.get(filename, 0)  # Default to 0 if not found
        image = cv2.imread(image_path)
        if image is None:
            raise FileNotFoundError(f"Image not found at path: {image_path}")
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        if self.transform:
            augmented = self.transform(image=image)
            image = augmented["image"]
        else:
            image = image.astype(np.float32)
        return image, class_label, severity_score, filename

    # New method to get labels
    def get_labels(self):
        return self.class_labels, list(self.severity_scores.values())
    
    

##### original data mean and variance 
mean = [0.4907, 0.2818, 0.34892]
std = [0.1352, 0.1340, 0.1515]
############################### old
train_transform = A.Compose([
    A.Resize(224, 224),
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.RandomBrightnessContrast(p=0.2),
    A.HueSaturationValue(p=0.2),
    A.CoarseDropout(
        max_holes=1,
        max_height=50,
        max_width=50,
        min_holes=1,
        min_height=50,
        min_width=50,
        p=0.5
    ),
    A.Rotate(limit=30, p=0.5),
    A.ShiftScaleRotate(
        shift_limit=0.1,
        scale_limit=0.1,
        rotate_limit=30,
        p=0.5
    ),
    A.GridDistortion(p=0.5),
    A.GaussianBlur(blur_limit=(3, 7), p=0.5),
    A.CLAHE(p=0.5),
    A.RGBShift(p=0.5),
    A.Normalize(mean=mean, std=std),
    ToTensorV2(),
])

###############################


test_transform = A.Compose([
    A.Resize(256, 256),
    A.CenterCrop(224, 224),
    A.Normalize(mean=mean, std=std),
    ToTensorV2(),
])
score_path='all_score_category.csv'
trainset = CustomDataset(train_dir,score_path,  transform=train_transform)
testset_pre = CustomDataset(test_pre,score_path,  transform=test_transform)

# %%
####model structure here
import timm
from torchvision import models

class EnsembleModel(nn.Module):
   def __init__(self):
       super().__init__()
       
       # DinoV2
       self.dinov2 = torch.hub.load('facebookresearch/dinov2', 'dinov2_vitb14_reg')
       # Freeze first few layers
       for param in list(self.dinov2.parameters())[:-4]:
           param.requires_grad = False
           
       self.dino_classifier = nn.Sequential(
           nn.Linear(768, 256),
           nn.ReLU(),
           nn.BatchNorm1d(256),
           nn.Dropout(0.3),
           nn.Linear(256, 2)
       )

       # EfficientNet
       self.efficient = timm.create_model('efficientnet_b0', pretrained=True)
       # Freeze initial layers
       for param in list(self.efficient.parameters())[:-4]: 
           param.requires_grad = False
           
       self.efficient.classifier = nn.Sequential(
           nn.Linear(1280, 256),
           nn.ReLU(),
           nn.BatchNorm1d(256),
           nn.Dropout(0.3),
           nn.Linear(256, 2)
       )

       # ResNet18 
       self.resnet = models.resnet18(pretrained=True)
       for param in list(self.resnet.parameters())[:-4]:
           param.requires_grad = False
           
       self.resnet.fc = nn.Sequential(
           nn.Linear(512, 256), 
           nn.ReLU(),
           nn.BatchNorm1d(256),
           nn.Dropout(0.3),
           nn.Linear(256, 2)
       )

   @torch.cuda.amp.autocast()
   def forward(self, x):
       dino_out = self.dino_classifier(self.dinov2(x))
       eff_out = self.efficient(x)
       res_out = self.resnet(x)
       return (dino_out + eff_out + res_out) / 3
    
model = EnsembleModel()
# Out:
# Using cache found in /home/tanmoy/.cache/torch/hub/facebookresearch_dinov2_main
# /home/tanmoy/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /home/tanmoy/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /home/tanmoy/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")
# /home/tanmoy/anaconda3/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/tanmoy/anaconda3/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# Create dataloaders
trainloader = DataLoader(trainset, batch_size=16, shuffle=True)
testloader = DataLoader(testset_pre, batch_size=16, shuffle=False)

#### model training and testing here
import torch.nn.functional as F
import numpy as np
from sklearn.metrics import roc_auc_score, f1_score, confusion_matrix, precision_recall_curve, auc
import torch.optim as optim

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)

def evaluate_model(model, dataloader, device):
   model.eval()
   all_class_preds = []
   all_class_labels = []
   all_class_probs = []
   
   with torch.no_grad():
       for images, class_labels, _, _ in dataloader:
           images = images.to(device)
           class_labels = class_labels.to(device)
           class_outputs = model(images)
           
           class_probs = F.softmax(class_outputs, dim=1).cpu().numpy()
           class_preds = np.argmax(class_probs, axis=1)
           
           all_class_probs.extend(class_probs)
           all_class_preds.extend(class_preds)
           all_class_labels.extend(class_labels.cpu().numpy())
   
   all_class_preds = np.array(all_class_preds)
   all_class_labels = np.array(all_class_labels) 
   all_class_probs = np.array(all_class_probs)

   tn, fp, fn, tp = confusion_matrix(all_class_labels, all_class_preds).ravel()
   metrics = {
       'auc': roc_auc_score(all_class_labels, all_class_probs[:,1]),
       'f1': f1_score(all_class_labels, all_class_preds),
       'specificity': tn / (tn + fp),
       'sensitivity': tp / (tp + fn),
       'accuracy': (tp + tn) / (tp + tn + fp + fn)
   }

   print("\nConfusion Matrix:")
   print(confusion_matrix(all_class_labels, all_class_preds))
   print(f"\nPerformance Metrics:")
   print(f"AUC: {metrics['auc']:.4f}")
   print(f"F1: {metrics['f1']:.4f}")
   print(f"Specificity: {metrics['specificity']:.4f}") 
   print(f"Sensitivity: {metrics['sensitivity']:.4f}")
   print(f"Accuracy: {metrics['accuracy']:.4f}")

   return metrics
# Out:
# cuda:0

# %%
# Training loop
model = model.to(device)
num_epochs = 150
best_f1 = 0.0
best_sens=0.0
# Training modifications
# optimizer = optim.AdamW(model.parameters(), lr=1e-3, weight_decay=0.01)
# scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', patience=3)
optimizer = optim.SGD(model.parameters(), lr=0.00002,
                      momentum=0.9, weight_decay=2e-3)
criterion = nn.CrossEntropyLoss(weight=torch.tensor([0.4, 0.6]).to(device))   #### summation should be 1

# Additional training loop changes
early_stopping_patience = 20
best_f1 = 0
no_improve = 0

scaler = GradScaler()

for epoch in range(num_epochs):
   model.train()
   running_loss = 0.0
   
   for images, labels, _, _ in trainloader:
       images, labels = images.to(device), labels.to(device)
       optimizer.zero_grad()
       
       with autocast():
           outputs = model(images)
           loss = criterion(outputs, labels)
           
       scaler.scale(loss).backward()
       scaler.step(optimizer)
       scaler.update()
       
       running_loss += loss.item()

   metrics = evaluate_model(model, testloader, device)
   performance_string = (f"Test Set Performance - AUC: {metrics['auc']:.2f}, F1 Score: {metrics['f1']:.2f}, Specificity: {metrics['specificity']:.2f}, Sensitivity: {metrics['sensitivity']:.2f}, Accuracy: {metrics['accuracy']:.2f}")
   with open(txt_fname, 'a') as file:
      file.write(f"Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss/len(trainloader):.4f}\n")
      file.write(performance_string+'\n')
   
   if metrics['f1'] > best_f1 and metrics['sensitivity'] > 0.6  and metrics['specificity']> 0.6 :
       best_f1 = metrics['f1']
       best_sens=metrics['sensitivity']
       torch.save(model.state_dict(), save_model_path)
       with open(txt_fname, 'a') as file:
          file.write("New model saved"+'\n')
       print(f'New model saved with F1: {best_f1} and sens: {best_sens} ')
       
   if no_improve >= early_stopping_patience:
       print("Early stopping triggered")
       break
# Out:
# Confusion Matrix:
# [[150  27]
#  [ 15   6]]
#
# Performance Metrics:
# AUC: 0.6879
# F1: 0.2222
# Specificity: 0.8475
# Sensitivity: 0.2857
# Accuracy: 0.7879
#
# Confusion Matrix:
# [[125  52]
#  [  9  12]]
#
# Performance Metrics:
# AUC: 0.6651
# F1: 0.2824
# Specificity: 0.7062
# Sensitivity: 0.5714
# Accuracy: 0.6919
#
# Confusion Matrix:
# [[116  61]
#  [  8  13]]
#
# Performance Metrics:
# AUC: 0.6488
# F1: 0.2737
# Specificity: 0.6554
# Sensitivity: 0.6190
# Accuracy: 0.6515
# New model saved with F1: 0.2736842105263158 and sens: 0.6190476190476191
#
# Confusion Matrix:
# [[99 78]
#  [ 6 15]]
#
# Performance Metrics:
# AUC: 0.6550
# F1: 0.2632
# Specificity: 0.5593
# Sensitivity: 0.7143
# Accuracy: 0.5758
#
# Confusion Matrix:
# [[95 82]
#  [ 5 16]]
#
# Performance Metrics:
# AUC: 0.6521
# F1: 0.2689
# Specificity: 0.5367
# Sensitivity: 0.7619
# Accuracy: 0.5606
#
# Confusion Matrix:
# [[99 78]
#  [ 5 16]]
#
# Performance Metrics:
# AUC: 0.6770
# F1: 0.2783
# Specificity: 0.5593
# Sensitivity: 0.7619
# Accuracy: 0.5808
#
# Confusion Matrix:
# [[93 84]
#  [ 4 17]]
#
# Performance Metrics:
# AUC: 0.6894
# F1: 0.2787
# Specificity: 0.5254
# Sensitivity: 0.8095
# Accuracy: 0.5556
#
# Confusion Matrix:
# [[82 95]
#  [ 5 16]]
#
# Performance Metrics:
# AUC: 0.6606
# F1: 0.2424
# Specificity: 0.4633
# Sensitivity: 0.7619
# Accuracy: 0.4949
#
# Confusion Matrix:
# [[90 87]
#  [ 8 13]]
#
# Performance Metrics:
# AUC: 0.6402
# F1: 0.2149
# Specificity: 0.5085
# Sensitivity: 0.6190
# Accuracy: 0.5202
#
# Confusion Matrix:
# [[91 86]
#  [ 8 13]]
#
# Performance Metrics:
# AUC: 0.6325
# F1: 0.2167
# Specificity: 0.5141
# Sensitivity: 0.6190
# Accuracy: 0.5253
#
# Confusion Matrix:
# [[89 88]
#  [ 7 14]]
#
# Performance Metrics:
# AUC: 0.6410
# F1: 0.2276
# Specificity: 0.5028
# Sensitivity: 0.6667
# Accuracy: 0.5202
#
# Confusion Matrix:
# [[99 78]
#  [ 7 14]]
#
# Performance Metrics:
# AUC: 0.6564
# F1: 0.2478
# Specificity: 0.5593
# Sensitivity: 0.6667
# Accuracy: 0.5707
#
# Confusion Matrix:
# [[98 79]
#  [ 9 12]]
#
# Performance Metrics:
# AUC: 0.6377
# F1: 0.2143
# Specificity: 0.5537
# Sensitivity: 0.5714
# Accuracy: 0.5556
#
# Confusion Matrix:
# [[92 85]
#  [ 9 12]]
#
# Performance Metrics:
# AUC: 0.6437
# F1: 0.2034
# Specificity: 0.5198
# Sensitivity: 0.5714
# Accuracy: 0.5253
#
# Confusion Matrix:
# [[85 92]
#  [ 6 15]]
#
# Performance Metrics:
# AUC: 0.6369
# F1: 0.2344
# Specificity: 0.4802
# Sensitivity: 0.7143
# Accuracy: 0.5051
#
# Confusion Matrix:
# [[79 98]
#  [ 4 17]]
#
# Performance Metrics:
# AUC: 0.6551
# F1: 0.2500
# Specificity: 0.4463
# Sensitivity: 0.8095
# Accuracy: 0.4848
#
# Confusion Matrix:
# [[90 87]
#  [ 7 14]]
#
# Performance Metrics:
# AUC: 0.6486
# F1: 0.2295
# Specificity: 0.5085
# Sensitivity: 0.6667
# Accuracy: 0.5253
#
# Confusion Matrix:
# [[89 88]
#  [ 8 13]]
#
# Performance Metrics:
# AUC: 0.6386
# F1: 0.2131
# Specificity: 0.5028
# Sensitivity: 0.6190
# Accuracy: 0.5152
#
# Confusion Matrix:
# [[101  76]
#  [  6  15]]
#
# Performance Metrics:
# AUC: 0.6691
# F1: 0.2679
# Specificity: 0.5706
# Sensitivity: 0.7143
# Accuracy: 0.5859
#
# Confusion Matrix:
# [[96 81]
#  [ 6 15]]
#
# Performance Metrics:
# AUC: 0.6538
# F1: 0.2564
# Specificity: 0.5424
# Sensitivity: 0.7143
# Accuracy: 0.5606
#
# Confusion Matrix:
# [[87 90]
#  [ 7 14]]
#
# Performance Metrics:
# AUC: 0.6345
# F1: 0.2240
# Specificity: 0.4915
# Sensitivity: 0.6667
# Accuracy: 0.5101
#
# Confusion Matrix:
# [[92 85]
#  [ 6 15]]
#
# Performance Metrics:
# AUC: 0.6490
# F1: 0.2479
# Specificity: 0.5198
# Sensitivity: 0.7143
# Accuracy: 0.5404
#
# Confusion Matrix:
# [[95 82]
#  [ 8 13]]
#
# Performance Metrics:
# AUC: 0.6352
# F1: 0.2241
# Specificity: 0.5367
# Sensitivity: 0.6190
# Accuracy: 0.5455
#
# Confusion Matrix:
# [[92 85]
#  [ 7 14]]
#
# Performance Metrics:
# AUC: 0.6248
# F1: 0.2333
# Specificity: 0.5198
# Sensitivity: 0.6667
# Accuracy: 0.5354
#
# Confusion Matrix:
# [[103  74]
#  [  8  13]]
#
# Performance Metrics:
# AUC: 0.6273
# F1: 0.2407
# Specificity: 0.5819
# Sensitivity: 0.6190
# Accuracy: 0.5859
#
# Confusion Matrix:
# [[94 83]
#  [ 7 14]]
#
# Performance Metrics:
# AUC: 0.6383
# F1: 0.2373
# Specificity: 0.5311
# Sensitivity: 0.6667
# Accuracy: 0.5455
#
# Confusion Matrix:
# [[91 86]
#  [ 7 14]]
#
# Performance Metrics:
# AUC: 0.6333
# F1: 0.2314
# Specificity: 0.5141
# Sensitivity: 0.6667
# Accuracy: 0.5303
#
# Confusion Matrix:
# [[89 88]
#  [ 7 14]]
#
# Performance Metrics:
# AUC: 0.6277
# F1: 0.2276
# Specificity: 0.5028
# Sensitivity: 0.6667
# Accuracy: 0.5202
#
# Confusion Matrix:
# [[89 88]
#  [ 5 16]]
#
# Performance Metrics:
# AUC: 0.6302
# F1: 0.2560
# Specificity: 0.5028
# Sensitivity: 0.7619
# Accuracy: 0.5303
#
# Confusion Matrix:
# [[87 90]
#  [ 6 15]]
#
# Performance Metrics:
# AUC: 0.6426
# F1: 0.2381
# Specificity: 0.4915
# Sensitivity: 0.7143
# Accuracy: 0.5152
#
# Confusion Matrix:
# [[100  77]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6426
# F1: 0.2500
# Specificity: 0.5650
# Sensitivity: 0.6667
# Accuracy: 0.5758
#
# Confusion Matrix:
# [[101  76]
#  [  6  15]]
#
# Performance Metrics:
# AUC: 0.6445
# F1: 0.2679
# Specificity: 0.5706
# Sensitivity: 0.7143
# Accuracy: 0.5859
#
# Confusion Matrix:
# [[92 85]
#  [ 5 16]]
#
# Performance Metrics:
# AUC: 0.6634
# F1: 0.2623
# Specificity: 0.5198
# Sensitivity: 0.7619
# Accuracy: 0.5455
#
# Confusion Matrix:
# [[93 84]
#  [ 7 14]]
#
# Performance Metrics:
# AUC: 0.6446
# F1: 0.2353
# Specificity: 0.5254
# Sensitivity: 0.6667
# Accuracy: 0.5404
#
# Confusion Matrix:
# [[108  69]
#  [  9  12]]
#
# Performance Metrics:
# AUC: 0.6386
# F1: 0.2353
# Specificity: 0.6102
# Sensitivity: 0.5714
# Accuracy: 0.6061
#
# Confusion Matrix:
# [[99 78]
#  [ 6 15]]
#
# Performance Metrics:
# AUC: 0.6542
# F1: 0.2632
# Specificity: 0.5593
# Sensitivity: 0.7143
# Accuracy: 0.5758
#
# Confusion Matrix:
# [[97 80]
#  [ 6 15]]
#
# Performance Metrics:
# AUC: 0.6513
# F1: 0.2586
# Specificity: 0.5480
# Sensitivity: 0.7143
# Accuracy: 0.5657
#
# Confusion Matrix:
# [[94 83]
#  [ 6 15]]
#
# Performance Metrics:
# AUC: 0.6481
# F1: 0.2521
# Specificity: 0.5311
# Sensitivity: 0.7143
# Accuracy: 0.5505
#
# Confusion Matrix:
# [[97 80]
#  [ 6 15]]
#
# Performance Metrics:
# AUC: 0.6630
# F1: 0.2586
# Specificity: 0.5480
# Sensitivity: 0.7143
# Accuracy: 0.5657
#
# Confusion Matrix:
# [[99 78]
#  [ 5 16]]
#
# Performance Metrics:
# AUC: 0.6801
# F1: 0.2783
# Specificity: 0.5593
# Sensitivity: 0.7619
# Accuracy: 0.5808
#
# Confusion Matrix:
# [[103  74]
#  [  8  13]]
#
# Performance Metrics:
# AUC: 0.6517
# F1: 0.2407
# Specificity: 0.5819
# Sensitivity: 0.6190
# Accuracy: 0.5859
#
# Confusion Matrix:
# [[105  72]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6573
# F1: 0.2617
# Specificity: 0.5932
# Sensitivity: 0.6667
# Accuracy: 0.6010
#
# Confusion Matrix:
# [[108  69]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6688
# F1: 0.2692
# Specificity: 0.6102
# Sensitivity: 0.6667
# Accuracy: 0.6162
#
# Confusion Matrix:
# [[108  69]
#  [  6  15]]
#
# Performance Metrics:
# AUC: 0.6645
# F1: 0.2857
# Specificity: 0.6102
# Sensitivity: 0.7143
# Accuracy: 0.6212
# New model saved with F1: 0.2857142857142857 and sens: 0.7142857142857143
#
# Confusion Matrix:
# [[113  64]
#  [  9  12]]
#
# Performance Metrics:
# AUC: 0.6540
# F1: 0.2474
# Specificity: 0.6384
# Sensitivity: 0.5714
# Accuracy: 0.6313
#
# Confusion Matrix:
# [[100  77]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6605
# F1: 0.2500
# Specificity: 0.5650
# Sensitivity: 0.6667
# Accuracy: 0.5758
#
# Confusion Matrix:
# [[96 81]
#  [ 6 15]]
#
# Performance Metrics:
# AUC: 0.6528
# F1: 0.2564
# Specificity: 0.5424
# Sensitivity: 0.7143
# Accuracy: 0.5606
#
# Confusion Matrix:
# [[97 80]
#  [ 7 14]]
#
# Performance Metrics:
# AUC: 0.6540
# F1: 0.2435
# Specificity: 0.5480
# Sensitivity: 0.6667
# Accuracy: 0.5606
#
# Confusion Matrix:
# [[100  77]
#  [  6  15]]
#
# Performance Metrics:
# AUC: 0.6585
# F1: 0.2655
# Specificity: 0.5650
# Sensitivity: 0.7143
# Accuracy: 0.5808
#
# Confusion Matrix:
# [[95 82]
#  [ 6 15]]
#
# Performance Metrics:
# AUC: 0.6301
# F1: 0.2542
# Specificity: 0.5367
# Sensitivity: 0.7143
# Accuracy: 0.5556
#
# Confusion Matrix:
# [[105  72]
#  [  8  13]]
#
# Performance Metrics:
# AUC: 0.6455
# F1: 0.2453
# Specificity: 0.5932
# Sensitivity: 0.6190
# Accuracy: 0.5960
#
# Confusion Matrix:
# [[99 78]
#  [ 6 15]]
#
# Performance Metrics:
# AUC: 0.6772
# F1: 0.2632
# Specificity: 0.5593
# Sensitivity: 0.7143
# Accuracy: 0.5758
#
# Confusion Matrix:
# [[98 79]
#  [ 5 16]]
#
# Performance Metrics:
# AUC: 0.6782
# F1: 0.2759
# Specificity: 0.5537
# Sensitivity: 0.7619
# Accuracy: 0.5758
#
# Confusion Matrix:
# [[97 80]
#  [ 6 15]]
#
# Performance Metrics:
# AUC: 0.6630
# F1: 0.2586
# Specificity: 0.5480
# Sensitivity: 0.7143
# Accuracy: 0.5657
#
# Confusion Matrix:
# [[95 82]
#  [ 6 15]]
#
# Performance Metrics:
# AUC: 0.6603
# F1: 0.2542
# Specificity: 0.5367
# Sensitivity: 0.7143
# Accuracy: 0.5556
#
# Confusion Matrix:
# [[95 82]
#  [ 7 14]]
#
# Performance Metrics:
# AUC: 0.6539
# F1: 0.2393
# Specificity: 0.5367
# Sensitivity: 0.6667
# Accuracy: 0.5505
#
# Confusion Matrix:
# [[93 84]
#  [ 6 15]]
#
# Performance Metrics:
# AUC: 0.6443
# F1: 0.2500
# Specificity: 0.5254
# Sensitivity: 0.7143
# Accuracy: 0.5455
#
# Confusion Matrix:
# [[101  76]
#  [  6  15]]
#
# Performance Metrics:
# AUC: 0.6396
# F1: 0.2679
# Specificity: 0.5706
# Sensitivity: 0.7143
# Accuracy: 0.5859
# Confusion Matrix:
# [[94 83]
#  [ 6 15]]
#
# Performance Metrics:
# AUC: 0.6715
# F1: 0.2521
# Specificity: 0.5311
# Sensitivity: 0.7143
# Accuracy: 0.5505
#
# Confusion Matrix:
# [[93 84]
#  [ 6 15]]
#
# Performance Metrics:
# AUC: 0.6671
# F1: 0.2500
# Specificity: 0.5254
# Sensitivity: 0.7143
# Accuracy: 0.5455
#
# Confusion Matrix:
# [[104  73]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6698
# F1: 0.2593
# Specificity: 0.5876
# Sensitivity: 0.6667
# Accuracy: 0.5960
#
# Confusion Matrix:
# [[107  70]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6667
# F1: 0.2667
# Specificity: 0.6045
# Sensitivity: 0.6667
# Accuracy: 0.6111
#
# Confusion Matrix:
# [[102  75]
#  [  6  15]]
#
# Performance Metrics:
# AUC: 0.6770
# F1: 0.2703
# Specificity: 0.5763
# Sensitivity: 0.7143
# Accuracy: 0.5909
#
# Confusion Matrix:
# [[100  77]
#  [  6  15]]
#
# Performance Metrics:
# AUC: 0.6507
# F1: 0.2655
# Specificity: 0.5650
# Sensitivity: 0.7143
# Accuracy: 0.5808
#
# Confusion Matrix:
# [[104  73]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6677
# F1: 0.2593
# Specificity: 0.5876
# Sensitivity: 0.6667
# Accuracy: 0.5960
#
# Confusion Matrix:
# [[118  59]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6696
# F1: 0.2979
# Specificity: 0.6667
# Sensitivity: 0.6667
# Accuracy: 0.6667
# New model saved with F1: 0.2978723404255319 and sens: 0.6666666666666666
#
# Confusion Matrix:
# [[103  74]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6811
# F1: 0.2569
# Specificity: 0.5819
# Sensitivity: 0.6667
# Accuracy: 0.5909
#
# Confusion Matrix:
# [[104  73]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6687
# F1: 0.2593
# Specificity: 0.5876
# Sensitivity: 0.6667
# Accuracy: 0.5960
#
# Confusion Matrix:
# [[107  70]
#  [  6  15]]
#
# Performance Metrics:
# AUC: 0.7008
# F1: 0.2830
# Specificity: 0.6045
# Sensitivity: 0.7143
# Accuracy: 0.6162
#
# Confusion Matrix:
# [[106  71]
#  [  6  15]]
#
# Performance Metrics:
# AUC: 0.6729
# F1: 0.2804
# Specificity: 0.5989
# Sensitivity: 0.7143
# Accuracy: 0.6111
#
# Confusion Matrix:
# [[101  76]
#  [  6  15]]
#
# Performance Metrics:
# AUC: 0.6781
# F1: 0.2679
# Specificity: 0.5706
# Sensitivity: 0.7143
# Accuracy: 0.5859
#
# Confusion Matrix:
# [[92 85]
#  [ 6 15]]
#
# Performance Metrics:
# AUC: 0.6542
# F1: 0.2479
# Specificity: 0.5198
# Sensitivity: 0.7143
# Accuracy: 0.5404
#
# Confusion Matrix:
# [[96 81]
#  [ 6 15]]
#
# Performance Metrics:
# AUC: 0.6606
# F1: 0.2564
# Specificity: 0.5424
# Sensitivity: 0.7143
# Accuracy: 0.5606
#
# Confusion Matrix:
# [[99 78]
#  [ 6 15]]
#
# Performance Metrics:
# AUC: 0.6607
# F1: 0.2632
# Specificity: 0.5593
# Sensitivity: 0.7143
# Accuracy: 0.5758
#
# Confusion Matrix:
# [[110  67]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6458
# F1: 0.2745
# Specificity: 0.6215
# Sensitivity: 0.6667
# Accuracy: 0.6263
#
# Confusion Matrix:
# [[107  70]
#  [  8  13]]
#
# Performance Metrics:
# AUC: 0.6497
# F1: 0.2500
# Specificity: 0.6045
# Sensitivity: 0.6190
# Accuracy: 0.6061
#
# Confusion Matrix:
# [[107  70]
#  [  6  15]]
#
# Performance Metrics:
# AUC: 0.6667
# F1: 0.2830
# Specificity: 0.6045
# Sensitivity: 0.7143
# Accuracy: 0.6162
#
# Confusion Matrix:
# [[109  68]
#  [  6  15]]
#
# Performance Metrics:
# AUC: 0.6819
# F1: 0.2885
# Specificity: 0.6158
# Sensitivity: 0.7143
# Accuracy: 0.6263
#
# Confusion Matrix:
# [[106  71]
#  [  5  16]]
#
# Performance Metrics:
# AUC: 0.6757
# F1: 0.2963
# Specificity: 0.5989
# Sensitivity: 0.7619
# Accuracy: 0.6162
#
# Confusion Matrix:
# [[111  66]
#  [  8  13]]
#
# Performance Metrics:
# AUC: 0.6574
# F1: 0.2600
# Specificity: 0.6271
# Sensitivity: 0.6190
# Accuracy: 0.6263
#
# Confusion Matrix:
# [[110  67]
#  [  6  15]]
#
# Performance Metrics:
# AUC: 0.6696
# F1: 0.2913
# Specificity: 0.6215
# Sensitivity: 0.7143
# Accuracy: 0.6313
#
# Confusion Matrix:
# [[108  69]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6657
# F1: 0.2692
# Specificity: 0.6102
# Sensitivity: 0.6667
# Accuracy: 0.6162
#
# Confusion Matrix:
# [[114  63]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6687
# F1: 0.2857
# Specificity: 0.6441
# Sensitivity: 0.6667
# Accuracy: 0.6465
#
# Confusion Matrix:
# [[107  70]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6552
# F1: 0.2667
# Specificity: 0.6045
# Sensitivity: 0.6667
# Accuracy: 0.6111
#
# Confusion Matrix:
# [[100  77]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6476
# F1: 0.2500
# Specificity: 0.5650
# Sensitivity: 0.6667
# Accuracy: 0.5758
#
# Confusion Matrix:
# [[111  66]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6706
# F1: 0.2772
# Specificity: 0.6271
# Sensitivity: 0.6667
# Accuracy: 0.6313
#
# Confusion Matrix:
# [[92 85]
#  [ 6 15]]
#
# Performance Metrics:
# AUC: 0.6661
# F1: 0.2479
# Specificity: 0.5198
# Sensitivity: 0.7143
# Accuracy: 0.5404
#
# Confusion Matrix:
# [[96 81]
#  [ 6 15]]
#
# Performance Metrics:
# AUC: 0.6649
# F1: 0.2564
# Specificity: 0.5424
# Sensitivity: 0.7143
# Accuracy: 0.5606
#
# Confusion Matrix:
# [[102  75]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6690
# F1: 0.2545
# Specificity: 0.5763
# Sensitivity: 0.6667
# Accuracy: 0.5859
#
# Confusion Matrix:
# [[99 78]
#  [ 7 14]]
#
# Performance Metrics:
# AUC: 0.6617
# F1: 0.2478
# Specificity: 0.5593
# Sensitivity: 0.6667
# Accuracy: 0.5707
#
# Confusion Matrix:
# [[94 83]
#  [ 8 13]]
#
# Performance Metrics:
# AUC: 0.6688
# F1: 0.2222
# Specificity: 0.5311
# Sensitivity: 0.6190
# Accuracy: 0.5404
#
# Confusion Matrix:
# [[111  66]
#  [  6  15]]
#
# Performance Metrics:
# AUC: 0.7072
# F1: 0.2941
# Specificity: 0.6271
# Sensitivity: 0.7143
# Accuracy: 0.6364
#
# Confusion Matrix:
# [[111  66]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6897
# F1: 0.2772
# Specificity: 0.6271
# Sensitivity: 0.6667
# Accuracy: 0.6313
#
# Confusion Matrix:
# [[106  71]
#  [  6  15]]
#
# Performance Metrics:
# AUC: 0.6848
# F1: 0.2804
# Specificity: 0.5989
# Sensitivity: 0.7143
# Accuracy: 0.6111
#
# Confusion Matrix:
# [[119  58]
#  [  6  15]]
#
# Performance Metrics:
# AUC: 0.6921
# F1: 0.3191
# Specificity: 0.6723
# Sensitivity: 0.7143
# Accuracy: 0.6768
# New model saved with F1: 0.3191489361702128 and sens: 0.7142857142857143
#
# Confusion Matrix:
# [[121  56]
#  [  6  15]]
#
# Performance Metrics:
# AUC: 0.7008
# F1: 0.3261
# Specificity: 0.6836
# Sensitivity: 0.7143
# Accuracy: 0.6869
# New model saved with F1: 0.32608695652173914 and sens: 0.7142857142857143
#
# Confusion Matrix:
# [[115  62]
#  [  6  15]]
#
# Performance Metrics:
# AUC: 0.6765
# F1: 0.3061
# Specificity: 0.6497
# Sensitivity: 0.7143
# Accuracy: 0.6566
#
# Confusion Matrix:
# [[107  70]
#  [  6  15]]
#
# Performance Metrics:
# AUC: 0.6922
# F1: 0.2830
# Specificity: 0.6045
# Sensitivity: 0.7143
# Accuracy: 0.6162
#
# Confusion Matrix:
# [[114  63]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6757
# F1: 0.2857
# Specificity: 0.6441
# Sensitivity: 0.6667
# Accuracy: 0.6465
#
# Confusion Matrix:
# [[105  72]
#  [  6  15]]
#
# Performance Metrics:
# AUC: 0.6624
# F1: 0.2778
# Specificity: 0.5932
# Sensitivity: 0.7143
# Accuracy: 0.6061
#
# Confusion Matrix:
# [[106  71]
#  [  8  13]]
#
# Performance Metrics:
# AUC: 0.6626
# F1: 0.2476
# Specificity: 0.5989
# Sensitivity: 0.6190
# Accuracy: 0.6010
#
# Confusion Matrix:
# [[108  69]
#  [  8  13]]
#
# Performance Metrics:
# AUC: 0.6659
# F1: 0.2524
# Specificity: 0.6102
# Sensitivity: 0.6190
# Accuracy: 0.6111
#
# Confusion Matrix:
# [[118  59]
#  [  8  13]]
#
# Performance Metrics:
# AUC: 0.6691
# F1: 0.2796
# Specificity: 0.6667
# Sensitivity: 0.6190
# Accuracy: 0.6616
#
# Confusion Matrix:
# [[122  55]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6859
# F1: 0.3111
# Specificity: 0.6893
# Sensitivity: 0.6667
# Accuracy: 0.6869
#
# Confusion Matrix:
# [[114  63]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6769
# F1: 0.2857
# Specificity: 0.6441
# Sensitivity: 0.6667
# Accuracy: 0.6465
#
# Confusion Matrix:
# [[123  54]
#  [  8  13]]
#
# Performance Metrics:
# AUC: 0.6929
# F1: 0.2955
# Specificity: 0.6949
# Sensitivity: 0.6190
# Accuracy: 0.6869
#
# Confusion Matrix:
# [[120  57]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6863
# F1: 0.3043
# Specificity: 0.6780
# Sensitivity: 0.6667
# Accuracy: 0.6768
#
# Confusion Matrix:
# [[119  58]
#  [  8  13]]
#
# Performance Metrics:
# AUC: 0.6910
# F1: 0.2826
# Specificity: 0.6723
# Sensitivity: 0.6190
# Accuracy: 0.6667
#
# Confusion Matrix:
# [[102  75]
#  [  6  15]]
#
# Performance Metrics:
# AUC: 0.6903
# F1: 0.2703
# Specificity: 0.5763
# Sensitivity: 0.7143
# Accuracy: 0.5909
#
# Confusion Matrix:
# [[114  63]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6854
# F1: 0.2857
# Specificity: 0.6441
# Sensitivity: 0.6667
# Accuracy: 0.6465
#
# Confusion Matrix:
# [[119  58]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6770
# F1: 0.3011
# Specificity: 0.6723
# Sensitivity: 0.6667
# Accuracy: 0.6717
#
# Confusion Matrix:
# [[110  67]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6906
# F1: 0.2745
# Specificity: 0.6215
# Sensitivity: 0.6667
# Accuracy: 0.6263
#
# Confusion Matrix:
# [[103  74]
#  [  6  15]]
#
# Performance Metrics:
# AUC: 0.6718
# F1: 0.2727
# Specificity: 0.5819
# Sensitivity: 0.7143
# Accuracy: 0.5960
#
# Confusion Matrix:
# [[103  74]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6698
# F1: 0.2569
# Specificity: 0.5819
# Sensitivity: 0.6667
# Accuracy: 0.5909
# Confusion Matrix:
# [[101  76]
#  [  6  15]]
#
# Performance Metrics:
# AUC: 0.6850
# F1: 0.2679
# Specificity: 0.5706
# Sensitivity: 0.7143
# Accuracy: 0.5859
#
# Confusion Matrix:
# [[113  64]
#  [  6  15]]
#
# Performance Metrics:
# AUC: 0.6965
# F1: 0.3000
# Specificity: 0.6384
# Sensitivity: 0.7143
# Accuracy: 0.6465
#
# Confusion Matrix:
# [[120  57]
#  [  8  13]]
#
# Performance Metrics:
# AUC: 0.6847
# F1: 0.2857
# Specificity: 0.6780
# Sensitivity: 0.6190
# Accuracy: 0.6717
#
# Confusion Matrix:
# [[108  69]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6817
# F1: 0.2692
# Specificity: 0.6102
# Sensitivity: 0.6667
# Accuracy: 0.6162
#
# Confusion Matrix:
# [[107  70]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6649
# F1: 0.2667
# Specificity: 0.6045
# Sensitivity: 0.6667
# Accuracy: 0.6111
#
# Confusion Matrix:
# [[115  62]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6778
# F1: 0.2887
# Specificity: 0.6497
# Sensitivity: 0.6667
# Accuracy: 0.6515
#
# Confusion Matrix:
# [[122  55]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6893
# F1: 0.3111
# Specificity: 0.6893
# Sensitivity: 0.6667
# Accuracy: 0.6869
#
# Confusion Matrix:
# [[110  67]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.7085
# F1: 0.2745
# Specificity: 0.6215
# Sensitivity: 0.6667
# Accuracy: 0.6263
#
# Confusion Matrix:
# [[105  72]
#  [  6  15]]
#
# Performance Metrics:
# AUC: 0.6937
# F1: 0.2778
# Specificity: 0.5932
# Sensitivity: 0.7143
# Accuracy: 0.6061
#
# Confusion Matrix:
# [[105  72]
#  [  6  15]]
#
# Performance Metrics:
# AUC: 0.6973
# F1: 0.2778
# Specificity: 0.5932
# Sensitivity: 0.7143
# Accuracy: 0.6061
#
# Confusion Matrix:
# [[105  72]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6833
# F1: 0.2617
# Specificity: 0.5932
# Sensitivity: 0.6667
# Accuracy: 0.6010
#
# Confusion Matrix:
# [[108  69]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6649
# F1: 0.2692
# Specificity: 0.6102
# Sensitivity: 0.6667
# Accuracy: 0.6162
#
# Confusion Matrix:
# [[115  62]
#  [  9  12]]
#
# Performance Metrics:
# AUC: 0.6573
# F1: 0.2526
# Specificity: 0.6497
# Sensitivity: 0.5714
# Accuracy: 0.6414
#
# Confusion Matrix:
# [[116  61]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6754
# F1: 0.2917
# Specificity: 0.6554
# Sensitivity: 0.6667
# Accuracy: 0.6566
#
# Confusion Matrix:
# [[128  49]
#  [  9  12]]
#
# Performance Metrics:
# AUC: 0.6648
# F1: 0.2927
# Specificity: 0.7232
# Sensitivity: 0.5714
# Accuracy: 0.7071
#
# Confusion Matrix:
# [[126  51]
#  [  9  12]]
#
# Performance Metrics:
# AUC: 0.6634
# F1: 0.2857
# Specificity: 0.7119
# Sensitivity: 0.5714
# Accuracy: 0.6970
#
# Confusion Matrix:
# [[126  51]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6821
# F1: 0.3256
# Specificity: 0.7119
# Sensitivity: 0.6667
# Accuracy: 0.7071
#
# Confusion Matrix:
# [[117  60]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6750
# F1: 0.2947
# Specificity: 0.6610
# Sensitivity: 0.6667
# Accuracy: 0.6616
#
# Confusion Matrix:
# [[118  59]
#  [  8  13]]
#
# Performance Metrics:
# AUC: 0.6720
# F1: 0.2796
# Specificity: 0.6667
# Sensitivity: 0.6190
# Accuracy: 0.6616
#
# Confusion Matrix:
# [[122  55]
#  [  9  12]]
#
# Performance Metrics:
# AUC: 0.6782
# F1: 0.2727
# Specificity: 0.6893
# Sensitivity: 0.5714
# Accuracy: 0.6768
#
# Confusion Matrix:
# [[126  51]
#  [  8  13]]
#
# Performance Metrics:
# AUC: 0.6797
# F1: 0.3059
# Specificity: 0.7119
# Sensitivity: 0.6190
# Accuracy: 0.7020
#
# Confusion Matrix:
# [[118  59]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.7045
# F1: 0.2979
# Specificity: 0.6667
# Sensitivity: 0.6667
# Accuracy: 0.6667
#
# Confusion Matrix:
# [[121  56]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.7011
# F1: 0.3077
# Specificity: 0.6836
# Sensitivity: 0.6667
# Accuracy: 0.6818
#
# Confusion Matrix:
# [[119  58]
#  [  6  15]]
#
# Performance Metrics:
# AUC: 0.7034
# F1: 0.3191
# Specificity: 0.6723
# Sensitivity: 0.7143
# Accuracy: 0.6768
#
# Confusion Matrix:
# [[114  63]
#  [  8  13]]
#
# Performance Metrics:
# AUC: 0.6800
# F1: 0.2680
# Specificity: 0.6441
# Sensitivity: 0.6190
# Accuracy: 0.6414
#
# Confusion Matrix:
# [[121  56]
#  [  8  13]]
#
# Performance Metrics:
# AUC: 0.6807
# F1: 0.2889
# Specificity: 0.6836
# Sensitivity: 0.6190
# Accuracy: 0.6768
#
# Confusion Matrix:
# [[118  59]
#  [  8  13]]
#
# Performance Metrics:
# AUC: 0.6759
# F1: 0.2796
# Specificity: 0.6667
# Sensitivity: 0.6190
# Accuracy: 0.6616
#
# Confusion Matrix:
# [[116  61]
#  [  6  15]]
#
# Performance Metrics:
# AUC: 0.7033
# F1: 0.3093
# Specificity: 0.6554
# Sensitivity: 0.7143
# Accuracy: 0.6616
#
# Confusion Matrix:
# [[113  64]
#  [  8  13]]
#
# Performance Metrics:
# AUC: 0.6929
# F1: 0.2653
# Specificity: 0.6384
# Sensitivity: 0.6190
# Accuracy: 0.6364
#
# Confusion Matrix:
# [[123  54]
#  [  9  12]]
#
# Performance Metrics:
# AUC: 0.6881
# F1: 0.2759
# Specificity: 0.6949
# Sensitivity: 0.5714
# Accuracy: 0.6818
#
# Confusion Matrix:
# [[116  61]
#  [  8  13]]
#
# Performance Metrics:
# AUC: 0.6750
# F1: 0.2737
# Specificity: 0.6554
# Sensitivity: 0.6190
# Accuracy: 0.6515
#
# Confusion Matrix:
# [[124  53]
#  [  9  12]]
#
# Performance Metrics:
# AUC: 0.6866
# F1: 0.2791
# Specificity: 0.7006
# Sensitivity: 0.5714
# Accuracy: 0.6869
#
# Confusion Matrix:
# [[125  52]
#  [  9  12]]
#
# Performance Metrics:
# AUC: 0.6590
# F1: 0.2824
# Specificity: 0.7062
# Sensitivity: 0.5714
# Accuracy: 0.6919
#
# Confusion Matrix:
# [[123  54]
#  [  9  12]]
#
# Performance Metrics:
# AUC: 0.6902
# F1: 0.2759
# Specificity: 0.6949
# Sensitivity: 0.5714
# Accuracy: 0.6818
#
# Confusion Matrix:
# [[123  54]
#  [  9  12]]
#
# Performance Metrics:
# AUC: 0.6885
# F1: 0.2759
# Specificity: 0.6949
# Sensitivity: 0.5714
# Accuracy: 0.6818
#
# Confusion Matrix:
# [[116  61]
#  [  7  14]]
#
# Performance Metrics:
# AUC: 0.6957
# F1: 0.2917
# Specificity: 0.6554
# Sensitivity: 0.6667
# Accuracy: 0.6566
